# %%
# !dir
FileDirectory = 'conda_list.txt'
with open('../conda_list.txt', 'r') as conda_list:
    with open('../requirements_PDU4.txt', 'w') as requirements:
        for line in conda_list:
            package = line.split('=')[0].strip()
            if package != '#':
                requirements.write(f"{package}\n")

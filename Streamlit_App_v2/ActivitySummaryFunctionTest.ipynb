# %%
import pandas as pd 
import numpy as np 
from importlib import reload
import datetime 
from PDU_Func import IO_Data, ActivitySummary,Authentification
# Out:
# 2023-04-17 01:36:50.112 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
UserAuthDict = {
  "data": {
    "user_name": "Admin(TEST)",
    "user_id": "MIH",
    "user_email": "irsyadhbtlh96@gmail.com",
    "user_company_name": "PDU",
    "user_cid": "",
    "status": "Authorized"
  },
  "verification": "verified"
}
WellInfoDict = {
  "cid": 9,
  "wid": 146,
  "WellName": "SMP AAE-05",
  "RigName": "8    PRA#1\nName: rig_name, dtype: string",
  "ActiveDate": "Timestamp('2021-06-28 00:00:00')",
  "EndDate": "Timestamp('2021-08-31 00:00:00')"
}
UserDateRange={
  "StartDate": datetime.date(2021, 7, 31),
  "StartTime": datetime.time(0, 0),
  "EndDate": datetime.date(2021, 8, 1),
  "EndTime": datetime.time(23, 59)
}
print("Start Time")
print(str(UserDateRange['StartDate']) + " " + str(UserDateRange['StartTime']))
print(str(UserDateRange['EndDate']) + " " + str(UserDateRange['EndTime']))
# Out:
# Start Time
# 2021-07-31 00:00:00
# 2021-08-01 23:59:00

# %% [markdown]
# ## get Activity Log

# %%
ActivityLog = IO_Data.DomeGetData(WellInfoDict, UserDateRange, table_type="ActivityLogTable")
ActivityLog
# Out:
# get ActivityLogTable data/table from DOME
#     id             DateTime        Date      Time            Activity  \
# 0  515  2021-07-31 00:57:39  2021-07-31  00:57:39             TRIP IN
# 1  516  2021-07-31 07:32:40  2021-07-31  07:32:40  DRILLING FORMATION
# 2  517  2021-08-01 08:56:23  2021-08-01  08:56:23          WIPER TRIP
# 3  518  2021-08-01 11:32:03  2021-08-01  11:32:03  DRILLING FORMATION
# 4  519  2021-08-01 21:18:50  2021-08-01  21:18:50          WIPER TRIP
# 5  520  2021-08-01 23:32:46  2021-08-01  23:32:46  DRILLING FORMATION
#
#   In-Slip Threshold     Remarks  PIC Section Size
# 0                63              MIH      12 1/4"
# 1                63              MIH      12 1/4"
# 2                63  Wiper Trip  MIH      12 1/4"
# 3                63              MIH      12 1/4"
# 4                63              MIH      12 1/4"
# 5                63              MIH      12 1/4"

# %% [markdown]
# ## get Realtime Sensor

# %%
WellInfoDict = {
  "cid": 9, # KS ORKA
  "wid": 146, # SMP AAE-05
  "WellName": "SMP AAE-05",
  "RigName": "8    PRA#1\nName: rig_name, dtype: string",
  "ActiveDate": "Timestamp('2021-06-28 00:00:00')",
  "EndDate": "Timestamp('2021-08-31 00:00:00')"
}
DateTimeRange = [
    "2021-07-31 00:00:00",
    "2021-07-31 23:59:00"
]
reload(IO_Data)
Out = IO_Data.DomeGetRealtimeSensorData(WellInfoDict, DateTimeRange)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 14
#       9 DateTimeRange = [
#      10     "2021-07-31 00:00:00",
#      11     "2021-07-31 23:59:00"
#      12 ]
#      13 reload(IO_Data)
# ---> 14 Out = IO_Data.DomeGetRealtimeSensorData(WellInfoDict, DateTimeRange)
#
# File c:\Users\irsya\Documents\Jiunx_Files\PROJECT\2021-PDU\01_PDU_python\Streamlit_App_v2\PDU_Func\IO_Data.py:351, in DomeGetRealtimeSensorData(WellInfoDict, UserDateRange)
#     346 def DomeGetRealtimeSensorData(WellInfoDict, UserDateRange):
#     347
#     348     # TODO: uncomment the code below if Realtime Data is ready
#     349     Data_params ={
#     350         "wid" : int(WellInfoDict['wid']),
# --> 351         "start" : str(UserDateRange['StartDate']) + " " + str(UserDateRange['StartTime']),
#     352         "end" : str(UserDateRange['EndDate']) + " " + str(UserDateRange['EndTime']),
#     353     }
#     355     # column_list = ["dt", "date", "time", "bitdepth", "md", "blockpos", "rop", "hklda", "woba", "torqa", "rpm", "stppress", "mudflowin",]
#     356
#     357     # WellData = (
#    (...)
#     364
#     365     # return Data_DF[column_list]
#     366     Realtime_DF = pd.read_excel(
#     367         "..\\Data\\Master_Report\\KS_ORKA\\AAE-05\\RealTime_test.xlsx",
#     368         # names=['raw']
#     369     )
#
# TypeError: list indices must be integers or slices, not str

# %%
reload(ActivitySummary)
ActivitySummaryTable = ActivitySummary.ActivitySummaryTable(WellInfoDict, DateTimeRange)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ActivitySummaryTable = ActivitySummary.ActivitySummaryTable(WellInfoDict, DateTimeRange)
#
# File c:\Users\irsya\Documents\Jiunx_Files\PROJECT\2021-PDU\01_PDU_python\Streamlit_App_v2\PDU_Func\ActivitySummary.py:46, in ActivitySummaryTable.__init__(self, WellInfoDict, UserDateRange)
#      43 def __init__(self, WellInfoDict:dict, UserDateRange:dict):
#      44     ColDataType = _DataType()
#      45     self.Data = pd.DataFrame(
# ---> 46                 columns = ColDataType.keys(),
#      47                 dtype=ColDataType,
#      48                 ),
#      49     self.WellInfoDict = WellInfoDict,
#      50     self.UserDateRange = UserDateRange,
#
# AttributeError: 'NoneType' object has no attribute 'keys'

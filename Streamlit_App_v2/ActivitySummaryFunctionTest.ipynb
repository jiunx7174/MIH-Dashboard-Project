# %%
import pandas as pd 
import numpy as np 
from importlib import reload
import datetime 
from PDU_Func import IO_Data, ActivitySummary,Authentification
# Out:
# 2023-04-26 20:13:51.033 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
UserAuthDict = {
  "data": {
    "user_name": "Admin(TEST)",
    "user_id": "MIH",
    "user_email": "irsyadhbtlh96@gmail.com",
    "user_company_name": "PDU",
    "user_cid": "",
    "status": "Authorized"
  },
  "verification": "verified"
}
WellInfoDict = {
  "cid": 9,
  "wid": 146,
  "WellName": "SMP AAE-05",
  "RigName": "8    PRA#1\nName: rig_name, dtype: string",
  "ActiveDate": "Timestamp('2021-06-28 00:00:00')",
  "EndDate": "Timestamp('2021-08-31 00:00:00')"
}
UserDateRange={
  "StartDate": datetime.date(2021, 7, 31),
  "StartTime": datetime.time(0, 0),
  "EndDate": datetime.date(2021, 8, 1),
  "EndTime": datetime.time(23, 59)
}
print("Start Time")
print(str(UserDateRange['StartDate']) + " " + str(UserDateRange['StartTime']))
print(str(UserDateRange['EndDate']) + " " + str(UserDateRange['EndTime']))
# Out:
# Start Time
# 2021-07-31 00:00:00
# 2021-08-01 23:59:00

# %% [markdown]
# ## get Activity Log

# %%
ActivityLog = IO_Data.DomeGetData(WellInfoDict, UserDateRange, table_type="ActivityLogTable")
ActivityLog
# Out:
# get ActivityLogTable data/table from DOME
#     id             DateTime        Date      Time            Activity  \
# 0  515  2021-07-31 00:57:39  2021-07-31  00:57:39             TRIP IN
# 1  516  2021-07-31 07:32:40  2021-07-31  07:32:40  DRILLING FORMATION
# 2  517  2021-08-01 08:56:23  2021-08-01  08:56:23          WIPER TRIP
# 3  518  2021-08-01 11:32:03  2021-08-01  11:32:03  DRILLING FORMATION
# 4  519  2021-08-01 21:18:50  2021-08-01  21:18:50          WIPER TRIP
# 5  520  2021-08-01 23:32:46  2021-08-01  23:32:46  DRILLING FORMATION
#
#   In-Slip Threshold     Remarks  PIC Section Size
# 0                63              MIH      12 1/4"
# 1                63              MIH      12 1/4"
# 2                63  Wiper Trip  MIH      12 1/4"
# 3                63              MIH      12 1/4"
# 4                63              MIH      12 1/4"
# 5                63              MIH      12 1/4"

# %% [markdown]
# ## get Realtime Sensor

# %%
WellInfoDict = {
  "cid": 9, # KS ORKA
  "wid": 146, # SMP AAE-05
  "WellName": "SMP AAE-05",
  "RigName": "8    PRA#1\nName: rig_name, dtype: string",
  "ActiveDate": "Timestamp('2021-06-28 00:00:00')",
  "EndDate": "Timestamp('2021-08-31 00:00:00')"
}
DateTimeRange = {
  "StartDate": "2021-07-28",
  "StartTime": "00:00:00",
  "EndDate": "2021-07-29",
  "EndTime": "23:59:00"
}
reload(IO_Data)
Out = IO_Data.DomeGetRealtimeSensorData(WellInfoDict, DateTimeRange)
Out
# Out:
#             Date      Time                  dt       md  bitdepth  blockpos  \
# 0     2021-07-28  07:30:00 2021-07-28 07:30:00   489.24    476.35     24.97
# 1     2021-07-28  07:30:05 2021-07-28 07:30:05   489.24    476.35     24.97
# 2     2021-07-28  07:30:10 2021-07-28 07:30:10   489.24    476.35     24.97
# 3      0.00   0.00   2.13  32.0  ...     622.51   88.32       NaN  nan
# 4      0.00   0.00   2.15  32.0  ...     622.51   87.92       NaN  nan
# ...     ...    ...    ...   ...  ...        ...     ...       ...  ...
# 25442  9.33  45.75  10.72  60.0  ...     865.34  110.04       NaN  nan
# 25443  9.33  45.54  11.09  59.0  ...     865.34  110.25       NaN  nan
# 25444  9.33  45.61  10.55  60.0  ...     865.34  110.18       NaN  nan
# 25445  8.13  45.61  10.99  59.0  ...     865.34  110.18       NaN  nan
# 25446  7.83  45.75  10.85  59.0  ...     865.34  110.04       NaN  nan
#
#       Section Size remarks In-Slip Threshold  SubActivity logic_status  \
# 0              nan     nan               NaN  FALSE/Check            0
# 1              nan     nan               NaN  FALSE/Check            0
# 2              nan     nan               NaN  FALSE/Check            0
# 3              nan     nan               NaN  FALSE/Check            0
# 4              nan     nan               NaN  FALSE/Check            0
# ...            ...     ...               ...          ...          ...
# 25442          nan     nan               NaN  FALSE/Check            0
# 25443          nan     nan               NaN  FALSE/Check            0
# 25444          nan     nan               NaN  FALSE/Check            0
# 25445          nan     nan               NaN  FALSE/Check            0
# 25446          nan     nan               NaN  FALSE/Check            0
#
#        isBitDepthMoving
# 0                 False
# 1                 False
# 2                 False
# 3                  True
# 4                 False
# ...                 ...
# 25442              True
# 25443              True
# 25444              True
# 25445              True
# 25446              True
#
# [25447 rows x 21 columns]

# %%
def GenerateDuration_DF_v4(RealTime_DB, DrillActivityList='default'):
    if DrillActivityList=='default':
        DrillActivityList = ["DRILLING FORMATION", 'CIRCULATE HOLE CLEANING','CONNECTION','DRILL OUT CEMENT',]


    RealTime_DB['dt'] = pd.to_datetime(RealTime_DB['dt'])
    RealTime_DB["LABEL_All"] =RealTime_DB['SubActivity'].astype(str)+'--'+RealTime_DB['Activity'].astype(str)

    # TODO , a funtion that check the latest hole depth
    Hole_Depth = 0
    list_dict_out = []
    for k,DF_Temp in RealTime_DB.groupby((RealTime_DB['LABEL_All'].shift() != RealTime_DB['LABEL_All']).cumsum()):

        # if not(("Hole_Depth" in locals()) or ("Hole_Depth" in globals())):
        #     Hole_Depth = 0

        list_temp = []

        # date = DF_Temp.head(1)['date'].values[0]

        # Time_start = pd.to_datetime(date + " " + DF_Temp.head(1)['time'].values[0])
        # Time_end_temp = DF_Temp.tail(1)['time'].values[0]
        # Time_end = pd.to_datetime(DF_Temp.tail(1)['date'].values[0] + " " + str((datetime.strptime(Time_end_temp, "%H:%M:%S") + timedelta(seconds=5)).time()))

        StartDateTime = DF_Temp['dt'].iloc[0]
        EndDateTime = DF_Temp['DateTime'].iloc[-1]
        # Time_start = DF_Temp.head(1)['time'].values[0]
        # Time_end_temp = DF_Temp.tail(1)['time'].values[0]
        # Time_end = str((datetime.strptime(Time_end_temp, "%H:%M:%S") + timedelta(seconds=5)).time())

        LABEL_Activity = DF_Temp['Activity'].iloc[0]
        LABEL_SubActivity = DF_Temp['SubActivity'].iloc[0]
        section_data = DF_Temp['Section Size'].iloc[0]
        pic_data = DF_Temp['PIC'].iloc[0]
        InSlip_Treshold_data = DF_Temp['In-Slip Threshold'].iloc[0]
        remarks_data = DF_Temp['remarks'].iloc[0]

        # Duration(minutes)
        Duration = (StartDateTime - EndDateTime).total_seconds() / 60.0 


        Hole_Depth_Temp = DF_Temp['md'].max()
        if float(Hole_Depth_Temp)>= float(Hole_Depth):
            Hole_Depth = Hole_Depth_Temp
        
        Bit_Depth = DF_Temp['bitdepth'].mean()

        MeterageDrilling = np.nan

        RotateDrilling = np.nan
        SlideDrilling = np.nan
        ReamingTime = np.nan
        ConnectionTime = np.nan

        OnBottomHours = np.nan
        StandDuration = np.nan

        if LABEL_Activity in DrillActivityList:
            MeterageDrilling = round((DF_Temp['md'].max()-DF_Temp['md'].min()),2)

        if LABEL_SubActivity == "Rotary Drilling":
            RotateDrilling = Duration

        if LABEL_SubActivity == "Slide Drilling":
            SlideDrilling = Duration

        if LABEL_SubActivity == "Reaming":
            ReamingTime = Duration
        if LABEL_SubActivity == "Connection":
            ConnectionTime = Duration


        list_dict_out.append(
            {
            'date':date,
            'Time_start':Time_start,
            'Time_end':Time_end,
            'date_time':date_time,
            'Duration(minutes)':Duration,
            'Hole Depth(max)':Hole_Depth,
            'Bit Depth(mean)':Bit_Depth,
            "Meterage(m)(Drilling)": MeterageDrilling,
            'RotateDrilling':RotateDrilling,
            'Slide Drilling':SlideDrilling,
            'ReamingTime':ReamingTime,
            'ConnectionTime':ConnectionTime,
            'On Bottom Hours':OnBottomHours,
            'Stand Duration': StandDuration,
            'LABEL_SubActivity': LABEL_SubActivity,
            "LABEL_Activity": LABEL_Activity,
            "PIC":pic_data,
            "Remarks":remarks_data,
            "Section":section_data,

            }
        )
    Duration_DB = pd.DataFrame.from_dict(list_dict_out, orient='columns')
    Duration_DB = Duration_DB.astype(
        {
            'date':'datetime64',
            'Duration(minutes)':'float',
            'Hole Depth(max)':'float',
            'Bit Depth(mean)':'float',
            "Meterage(m)(Drilling)":'float',
            'RotateDrilling':'float',
            'Slide Drilling':'float',
            'ReamingTime':'float',
            'ConnectionTime':'float',
            'On Bottom Hours':'float',
            'Stand Duration':'float',
            "LABEL_SubActivity":'str', 
            "LABEL_Activity":'str',
            "PIC":'str',
            "Remarks":'str',
            "Section":'str',
        }
    )

    listSetDecimals = [
            'Duration(minutes)',
            'Hole Depth(max)',
            'Bit Depth(mean)',
            "Meterage(m)(Drilling)",
            'RotateDrilling',
            'Slide Drilling',
            'ReamingTime',
            'ConnectionTime',
            'On Bottom Hours',
            'Stand Duration',
    ]
    for ColumnName in listSetDecimals:
        # print(ColumnName)
        Duration_DB[ColumnName] = Duration_DB[ColumnName].round(decimals=2)

    # rounded_df = df.round(decimals=2)
    return Duration_DB

GenerateDuration_DF_v4(OutTest)

# %%
# GenerateDuration
## Aggregate 1

# as it is
# datetime start 
# datetime end 
# date 
# well name
# activity
# sub-activity
# section size
# PIC
# in-slip threshold
# remarks

# 
# calculate on the fly
# Duration 
# Hole Depth 
# Bit Depth 
# Drilling Meterage
# Rotate Drilling Time 
# Slide Drilling Time
# Reaming Time
# Connection Time


# LabelStand
## Aggregate 2
# Connection Activity
# On Bottom Duration 
# Stand Duration

# %%
OutTest.columns
# Out:
# Index(['Date', 'Time', 'dt', 'md', 'bitdepth', 'blockpos', 'rop', 'woba',
#        'torqa', 'rpm', 'stppress', 'mudflowin', 'hklda', 'Activity', 'PIC',
#        'Section Size', 'remarks', 'In-Slip Threshold', 'SubActivity',
#        'logic_status', 'isBitDepthMoving'],
#       dtype='object')

# %%
test = pd.DataFrame(
    {
    "a":[1,2,np.nan,4],
    "b":[1,2,3,4],
    }
)
test.mean()
# Out:
# a    2.333333
# b    2.500000
# dtype: float64

# %%
7/4
# Out:
# 1.75

# %% [markdown]
# ## Realtime Sensor Download parallel

# %%
from datetime import datetime
import requests
import json
import time
from Page import Welcome
from datetime import datetime
import pandas as pd
def DomeGetRealtimeSensorData(WellInfoDict, UserDateRange):
    # UserDateRange = {
    #         "StartDate": UserDateRange['StartDate'].strftime('%Y-%m-%d'),
    #         "StartTime": UserDateRange['StartTime'].strftime('%H:%M:%S'),
    #         "EndDate": UserDateRange['EndDate'].strftime('%Y-%m-%d'),
    #         "EndTime": UserDateRange['EndTime'].strftime('%H:%M:%S'),
    #         }

    # TODO: uncomment the code below if Realtime Data is ready
    Data_params ={
        "wid" : int(WellInfoDict['wid']),
        "start" : str(UserDateRange['StartDate']) + " " + str(UserDateRange['StartTime']),
        "end" : str(UserDateRange['EndDate']) + " " + str(UserDateRange['EndTime']),
    }
    

    column_list = ["dt", "date", "time", "bitdepth", "md", "blockpos", "rop", "hklda", "woba", "torqa", "rpm", "stppress", "mudflowin",]

    WellData = (
        (
            # requests.get("https://pdumitradome.id/dome_api/rtdc/rtdc/get_data", data=json.dumps(Data_params))
            requests.get("http://khansadev.xyz/dome_api/rtdc/get_data", data=json.dumps(Data_params))
        ).text
    )
    Realtime_DF = pd.json_normalize(json.loads(WellData), record_path='result')
    Realtime_DF['dt'] = Realtime_DF['dt'].astype('datetime64[ns]')
    start = datetime.strptime(Data_params['start'], '%Y-%m-%d %H:%M:%S')
    end = datetime.strptime(Data_params['end'], '%Y-%m-%d %H:%M:%S')
    mask = (Realtime_DF['dt'] > start) & (Realtime_DF['dt'] <= end)
    filtered_DF = Realtime_DF[mask]
    return filtered_DF[column_list]


UserDateRange = {
  "StartDate": "2023-04-28",
  "StartTime": "01:10:00",
  "EndDate": "2023-04-29",
  "EndTime": "23:10:00"
}
WellInfoDict = {
  "cid": 74,
  "wid": 243,
  "WellName": "IJN 2-1",
  "RigName": "2    EPI-9\nName: rig_name, dtype: string",
  "ActiveDate": "Timestamp('2023-04-05 00:00:00')",
  "EndDate": "Timestamp('2023-05-31 00:00:00')"
}

# DomeGetRealtimeSensorData(WellInfoDict, UserDateRange)

# %%
def splitDateTime(UserDateRange, hours=0.5):
    startDateTimeStr = UserDateRange['StartDate'] + ' ' + UserDateRange['StartTime']
    endDateTimeStr = UserDateRange['EndDate'] + ' ' + UserDateRange['EndTime']


# 2023-04-29 22:10:00 - 2023-04-29 22:40:00
# 2023-04-29 22:40:00 - 2023-04-29 23:10:00

# %%
import time
import numpy as np
from tqdm import tqdm
def DomeGetRealtimeSensorData_v2(WellInfoDict, UserDateRange, hours=0.5):
    # UserDateRange = {
    #         "StartDate": UserDateRange['StartDate'].strftime('%Y-%m-%d'),
    #         "StartTime": UserDateRange['StartTime'].strftime('%H:%M:%S'),
    #         "EndDate": UserDateRange['EndDate'].strftime('%Y-%m-%d'),
    #         "EndTime": UserDateRange['EndTime'].strftime('%H:%M:%S'),
    #         }
    StartDateTimeList,EndDateTimeList = splitDateTime(UserDateRange, hours=hours)
    # TODO: uncomment the code below if Realtime Data is ready
    column_list = ["dt", "date", "time", "bitdepth", "md", "blockpos", "rop", "hklda", "woba", "torqa", "rpm", "stppress", "mudflowin",]
    Realtime_List = []
    time_elapsed = []
    i = 0
    StartEndList=list(zip(StartDateTimeList,EndDateTimeList))

    for StartEnd in tqdm(((StartEndList))):
        StartDateTime,EndDateTime = StartEnd
        loopStartTime = time.time()
        Data_params ={
            "wid" : int(WellInfoDict['wid']),
            "start" : str(StartDateTime),
            "end" : str(EndDateTime),
        }
        # print(Data_params)

        WellData = json.loads((
            (
                # requests.get("https://pdumitradome.id/dome_api/rtdc/rtdc/get_data", data=json.dumps(Data_params))
                requests.get("http://khansadev.xyz/dome_api/rtdc/get_data", data=json.dumps(Data_params))
            ).text
        ))
        if WellData['status'] != 200:
            raise KeyError (WellData['message'])
        
        Realtime_DF_temp = pd.json_normalize((WellData), record_path='result')
        Realtime_DF_temp['dt'] = Realtime_DF_temp['dt'].astype('datetime64[ns]')
        Realtime_List.append(Realtime_DF_temp)
        loopEndTime = time.time()
        i=i+1
        time_elapsed.append(loopEndTime-loopStartTime)
        # print(f"Iteration {i}: {(loopEndTime-loopStartTime):.4f} seconds")
    Realtime_DF = pd.concat(Realtime_List, axis=0, ignore_index=True)

    start = str(UserDateRange['StartDate']) + " " + str(UserDateRange['StartTime'])
    end = str(UserDateRange['EndDate']) + " " + str(UserDateRange['EndTime'])
    mask = (Realtime_DF['dt'] > start) & (Realtime_DF['dt'] <= end)
    filtered_DF = Realtime_DF[mask]
    print( np.mean(time_elapsed))
    return filtered_DF[column_list]
starttime = time.time()
DomeGetRealtimeSensorData_v2(WellInfoDict, UserDateRange, hours=0.5)
print(time.time() - starttime)
# Out:
# 100%|██████████| 92/92 [01:43<00:00,  1.12s/it]
# 1.121764600276947
# 104.67624258995056

# %%
from multiprocessing.pool import ThreadPool
from functools import partial

def DomeGetRealtimeSensorDataSingleDate(WellInfoDict, StartDateTime, EndDateTime):
    # UserDateRange = {
    #         "StartDate": UserDateRange['StartDate'].strftime('%Y-%m-%d'),
    #         "StartTime": UserDateRange['StartTime'].strftime('%H:%M:%S'),
    #         "EndDate": UserDateRange['EndDate'].strftime('%Y-%m-%d'),
    #         "EndTime": UserDateRange['EndTime'].strftime('%H:%M:%S'),
    #         }

    # TODO: uncomment the code below if Realtime Data is ready
    column_list = ["dt", "date", "time", "bitdepth", "md", "blockpos", "rop", "hklda", "woba", "torqa", "rpm", "stppress", "mudflowin",]

    # for StartDateTime,EndDateTime in zip(StartDateTimeList,EndDateTimeList):
    Data_params ={
        "wid" : int(WellInfoDict['wid']),
        "start" : str(StartDateTime),
        "end" : str(EndDateTime),
    }

    WellData = json.loads((
        (
            # requests.get("https://pdumitradome.id/dome_api/rtdc/rtdc/get_data", data=json.dumps(Data_params))
            requests.get("http://khansadev.xyz/dome_api/rtdc/get_data", data=json.dumps(Data_params))
        ).text
    ))
    if WellData['status'] != 200:
        raise KeyError (WellData['message'])
    
    Realtime_DF = pd.json_normalize((WellData), record_path='result')
    Realtime_DF['dt'] = Realtime_DF['dt'].astype('datetime64[ns]')

        # print(f"Iteration {i}: {(loopEndTime-loopStartTime):.4f} seconds")


    # start = str(UserDateRange['StartDate']) + " " + str(UserDateRange['StartTime'])
    # end = str(UserDateRange['EndDate']) + " " + str(UserDateRange['EndTime'])
    # start = datetime.strptime(Data_params['start'], '%Y-%m-%d %H:%M:%S')
    # end = datetime.strptime(Data_params['end'], '%Y-%m-%d %H:%M:%S')
    # mask = (Realtime_DF['dt'] > start) & (Realtime_DF['dt'] <= end)
    # filtered_DF = Realtime_DF[mask]

    return Realtime_DF[column_list]

def DomeGetRealtimeSensorData_MultiCPU(WellInfoDict, UserDateRange,hours=0.5)

    StartDateTimeList,EndDateTimeList = splitDateTime(UserDateRange, hours=0.5)
    partial_get_data = partial(DomeGetRealtimeSensorDataSingleDate, WellInfoDict)

    with ThreadPool(processes=8) as pool:
        Realtime_List = pool.starmap(partial_get_data, zip(StartDateTimeList,EndDateTimeList))
    Realtime_DF = pd.concat(Realtime_List, axis=0, ignore_index=True)
    start = str(UserDateRange['StartDate']) + " " + str(UserDateRange['StartTime'])
    end = str(UserDateRange['EndDate']) + " " + str(UserDateRange['EndTime'])
    mask = (Realtime_DF['dt'] > start) & (Realtime_DF['dt'] <= end)
    filtered_DF = Realtime_DF[mask]
    return filtered_DF
# Out:
# [                     dt        date      time bitdepth      md blockpos  \
#  0   2023-04-28 01:10:03  2023-04-28  01:10:03   657.59  657.59     6.87
#  1   2023-04-28 01:10:08  2023-04-28  01:10:08   657.61  657.61     6.84
#  2   2023-04-28 01:10:13  2023-04-28  01:10:13   657.64  657.64     6.81
#  3   2023-04-28 01:10:18  2023-04-28  01:10:18   657.68  657.68     6.78
#  4   2023-04-28 01:10:23  2023-04-28  01:10:23   657.68  657.68     6.78
#  ..                  ...         ...       ...      ...     ...      ...
#  355 2023-04-28 01:39:38  2023-04-28  01:39:38   662.73  662.73     1.72
#  356 2023-04-28 01:39:43  2023-04-28  01:39:43   662.74  662.74     1.71
#  357 2023-04-28 01:39:48  2023-04-28  01:39:48   662.77  662.77     1.69
#  358 2023-04-28 01:39:53  2023-04-28  01:39:53   662.79  662.79     1.66
#  359 2023-04-28 01:39:58  2023-04-28  01:39:58   662.81  662.81     1.65
#
#         rop   hklda   woba torqa    rpm stppress mudflowin
#  ..                  ...         ...       ...      ...     ...      ...   ...
#  355 2023-04-29 22:39:37  2023-04-29  22:39:37   875.75  875.75    20.21  4.65
#  356 2023-04-29 22:39:42  2023-04-29  22:39:42   875.77  875.77    20.19  4.65
#  357 2023-04-29 22:39:47  2023-04-29  22:39:47   875.79  875.79    20.17  4.65
#  358 2023-04-29 22:39:52  2023-04-29  22:39:52   875.80  875.80    20.16  4.65
#  359 2023-04-29 22:39:57  2023-04-29  22:39:57   875.80  875.80    20.15  4.65
#
#        hklda   woba torqa   rpm stppress mudflowin
#  0    137.32  41.29  0.00  0.00  1506.06    868.82
#  1    136.96  41.65  0.00  0.00  1507.27    869.81
#  2    137.46  41.15  0.00  0.00  1507.88    868.82
#  3    138.18  40.43  0.00  0.00  1502.73    868.82
#  4    137.96  40.65  0.00  0.00  1499.20    869.81
#  ..      ...    ...   ...   ...      ...       ...
#  355  140.18  38.43  0.00  0.00  1546.36    867.83
#  356  140.15  38.46  0.00  0.00  1544.44    867.99
#  357  138.10  40.51  0.00  0.00  1547.88    865.84
#  358  136.88  41.73  0.00  0.00  1557.58    867.83
#  359  137.24  41.37  0.00  0.00  1555.46    868.82
#
#  [360 rows x 13 columns],
#                       dt        date      time bitdepth      md blockpos   rop  \
#  0   2023-04-29 22:40:02  2023-04-29  22:40:02   875.82  875.82    20.14  4.65
#  1   2023-04-29 22:40:07  2023-04-29  22:40:07   875.83  875.83    20.13  4.65
#  2   2023-04-29 22:40:12  2023-04-29  22:40:12   875.84  875.84    20.12  4.65
#  3   2023-04-29 22:40:17  2023-04-29  22:40:17   875.85  875.85    20.11  4.65
#  4   2023-04-29 22:40:22  2023-04-29  22:40:22   875.85  875.85    20.10  4.65
#  ..                  ...         ...       ...      ...     ...      ...   ...
#  355 2023-04-29 23:09:37  2023-04-29  23:09:37   877.20  877.20    18.76  4.79
#  356 2023-04-29 23:09:42  2023-04-29  23:09:42   877.21  877.21    18.75  4.79
#  357 2023-04-29 23:09:47  2023-04-29  23:09:47   877.21  877.21    18.75  4.79
#  358 2023-04-29 23:09:52  2023-04-29  23:09:52   877.22  877.22    18.74  4.79
#  359 2023-04-29 23:09:57  2023-04-29  23:09:57   877.24  877.24    18.72  4.79
#
#        hklda   woba torqa    rpm stppress mudflowin
#  0    137.53  41.08  0.00   0.00  1552.12    867.83
#  1    136.96  41.65  0.00   0.00  1547.27    868.82
#  2    136.67  41.94  0.00   0.00  1544.54    868.82
#  3    135.31  43.30  0.00   0.00  1548.18    868.82
#  4    136.25  42.36  0.00   0.00  1543.94    868.82
#  ..      ...    ...   ...    ...      ...       ...
#  355  156.37  29.42  6.60  50.00  1335.86    873.79
#  356  156.58  29.21  6.52  50.00  1357.93    873.79
#  357  157.37  28.42  6.38  50.00  1377.01    873.79
#  358  158.26  26.37  6.43  50.00  1402.34    873.79
#  359  157.54  27.09  6.41  50.00  1422.99    873.79
#
#  [360 rows x 13 columns]]

# %%
import multiprocessing
from multiprocessing.pool import ThreadPool

# Get the number of available CPU cores
num_cores = multiprocessing.cpu_count()
num_cores
# Out:
# 8

# %%
a= [1,2,3]
b=[4,3,2]
out = list(zip(a,b))
out
# Out:
# [(1, 4), (2, 3), (3, 2)]

# %%
StartEnd,EndStart = out[0]

# %%
EndStart
# Out:
# 4

# %%
import pandas as pd 
import numpy as np 
from importlib import reload
import datetime 
from PDU_Func import IO_Data, ActivitySummary,Authentification
# Out:
# 2023-04-13 23:37:59.956 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
UserAuthDict = {
  "data": {
    "user_name": "Admin(TEST)",
    "user_id": "MIH",
    "user_email": "irsyadhbtlh96@gmail.com",
    "user_company_name": "PDU",
    "user_cid": "",
    "status": "Authorized"
  },
  "verification": "verified"
}
WellInfoDict = {
  "cid": 9,
  "wid": 146,
  "WellName": "SMP AAE-05",
  "RigName": "8    PRA#1\nName: rig_name, dtype: string",
  "ActiveDate": "Timestamp('2021-06-28 00:00:00')",
  "EndDate": "Timestamp('2021-08-31 00:00:00')"
}
UserDateRange={
  "StartDate": datetime.date(2021, 7, 31),
  "StartTime": datetime.time(0, 0),
  "EndDate": datetime.date(2021, 8, 1),
  "EndTime": datetime.time(23, 59)
}
print("Start Time")
print(str(UserDateRange['StartDate']) + " " + str(UserDateRange['StartTime']))
print(str(UserDateRange['EndDate']) + " " + str(UserDateRange['EndTime']))
# Out:
# Start Time
# 2021-07-31 00:00:00
# 2021-08-01 23:59:00

# %% [markdown]
# ## get Activity Log

# %%
ActivityLog = IO_Data.DomeGetData(WellInfoDict, UserDateRange, table_type="ActivityLogTable")
ActivityLog
# Out:
# get ActivityLogTable data/table from DOME
#     id             DateTime        Date      Time            Activity  \
# 0  515  2021-07-31 00:57:39  2021-07-31  00:57:39             TRIP IN
# 1  516  2021-07-31 07:32:40  2021-07-31  07:32:40  DRILLING FORMATION
# 2  517  2021-08-01 08:56:23  2021-08-01  08:56:23          WIPER TRIP
# 3  518  2021-08-01 11:32:03  2021-08-01  11:32:03  DRILLING FORMATION
# 4  519  2021-08-01 21:18:50  2021-08-01  21:18:50          WIPER TRIP
# 5  520  2021-08-01 23:32:46  2021-08-01  23:32:46  DRILLING FORMATION
#
#   In-Slip Threshold     Remarks  PIC Section Size
# 0                63              MIH      12 1/4"
# 1                63              MIH      12 1/4"
# 2                63  Wiper Trip  MIH      12 1/4"
# 3                63              MIH      12 1/4"
# 4                63              MIH      12 1/4"
# 5                63              MIH      12 1/4"

# %% [markdown]
# ## get Realtime Sensor

# %%
WellInfoDict = {
  "cid": 9, # KS ORKA
  "wid": 146, # SMP AAE-05
  "WellName": "SMP AAE-05",
  "RigName": "8    PRA#1\nName: rig_name, dtype: string",
  "ActiveDate": "Timestamp('2021-06-28 00:00:00')",
  "EndDate": "Timestamp('2021-08-31 00:00:00')"
}
DateTimeRange = [
    "2021-07-31 00:00:00",
    "2021-07-31 23:59:00"
]
reload(IO_Data)
Out = IO_Data.DomeGetRealtimeSensorData(WellInfoDict, DateTimeRange)
# Out:
# {"status":200,"result":[]}
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 14
#       9 DateTimeRange = [
#      10     "2021-07-31 00:00:00",
#      11     "2021-07-31 23:59:00"
#      12 ]
#      13 reload(IO_Data)
# ---> 14 Out = IO_Data.DomeGetRealtimeSensorData(WellInfoDict, DateTimeRange)
#
# File c:\Users\irsya\Documents\Jiunx_Files\PROJECT\2021-PDU\01_PDU_python\Streamlit_App_v2\PDU_Func\IO_Data.py:367, in DomeGetRealtimeSensorData(WellInfoDict, DateTimeRange)
#     365 print(Data_DF)
#     366 # print(Data_DF.head(5))
# --> 367 return Data_DF[column_list]
#
# File c:\Users\irsya\Miniconda3\envs\PDU_2\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\irsya\Miniconda3\envs\PDU_2\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\irsya\Miniconda3\envs\PDU_2\lib\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['dt', 'date', 'time', 'bitdepth', 'md', 'blockpos', 'rop', 'hklda',\n       'woba', 'torqa', 'rpm', 'stppress', 'mudflowin'],\n      dtype='object')] are in the [columns]"

# %%
Realtime_DF = pd.read_csv(
    
)

# %%
import pandas as pd 
import numpy as np 
from PDU_Func import IO_Data
import datetime

# %%
UserDateRange = {
  "StartDate": datetime.date(2020, 4, 28),
  "StartTime": datetime.time(21, 30),
  "EndDate": datetime.date(2023, 4, 29),
  "EndTime": datetime.time(6, 30)
}
WellInfoDict = {
  "cid": 74,
  "wid": 243,
  "WellName": "IJN 2-1",
  "RigName": "3    EPI-9\nName: rig_name, dtype: string",
  "ActiveDate": "2023-04-05",
  "EndDate": "2023-05-31"
}
UserDateRange
# Out:
# {'StartDate': datetime.date(2020, 4, 28),
#  'StartTime': datetime.time(21, 30),
#  'EndDate': datetime.date(2023, 4, 29),
#  'EndTime': datetime.time(6, 30)}

# %%
IO_Data.DomeGetData(WellInfoDict, UserDateRange, table_type="ActivityLogTable")
# Out:
# get ActivityLogTable data/table from DOME
# {'status': 200, 'result': []}
#    id                   DateTime        Date      Time Activity  \
# 0   1 2023-05-18 00:51:23.893986  2020-04-28  21:30:00      N/A
#
#    In-Slip Threshold Remarks PIC Section Size
# 0                 63

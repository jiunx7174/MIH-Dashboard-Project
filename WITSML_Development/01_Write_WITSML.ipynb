# %%
LibDir = r'..\Streamlit_App_v3'


import os 
os.sys.path.append(LibDir)

from PDU_Func import IO_Data, Authentification
# Out:
# 2025-04-07 04:41:14.864 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-04-07 04:41:14.864 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
UserAuthDict = Authentification.getUserID({'ID':'71unxv'})
display(UserAuthDict)
# Out:
# {'data': {'user_name': 'Admin(TEST)',
#   'user_id': 'MIH',
#   'user_email': 'irsyadhbtlh96@gmail.com',
#   'user_company_name': 'PDU',
#   'user_cid': '',
#   'streamlit_version': 'Streamlit version: 1.36.0',
#   'status': 'Authorized'},
#  'verification': 'verified'}

# %%
IO_Data.getAvailableCompanyDF(UserAuthDict)
SelectComp = "PETROCHINA INTERNATIONAL JABUNG LTD"
IO_Data.getAvailableWellDF(SelectComp,UserAuthDict)
SelectWell= "GEMAH-80"
WellInfoDict = IO_Data.getWellInfoDict(UserAuthDict, SelectComp, SelectWell)
display(WellInfoDict)
# Out:
# {'cid': 5,
#  'wid': 422,
#  'WellName': 'GEMAH-80',
#  'RigName': 36    RIG#26
#  Name: rig_name, dtype: string,
#  'ActiveDate': '2025-03-26',
#  'EndDate': '2025-04-30'}

# %%
    # startDateTimeStr = UserDateRange['StartDate'] + ' ' + UserDateRange['StartTime']
    # endDateTimeStr = UserDateRange['EndDate'] + ' ' + UserDateRange['EndTime']
from datetime import datetime

UserDateRange = {}
UserDateRange['StartDate'] = '2025-04-06'
UserDateRange['StartTime'] = '00:00:00'
UserDateRange['EndDate'] = '2025-04-06'
UserDateRange['EndTime'] = '10:00:00'
UserDateRange['StartDate'] = datetime.strptime(UserDateRange['StartDate'], '%Y-%m-%d').date()
UserDateRange['StartTime'] = datetime.strptime(UserDateRange['StartTime'], '%H:%M:%S').time()
UserDateRange['EndDate'] = datetime.strptime(UserDateRange['EndDate'], '%Y-%m-%d').date()
UserDateRange['EndTime'] = datetime.strptime(UserDateRange['EndTime'], '%H:%M:%S').time()

# %%
RealtimeData = IO_Data.DomeGetRealtimeSensorData(WellInfoDict, 
                          UserDateRange, 
                          hours=1, 
                          show_progress=False,
                          runOnStreamlit=False, 
                          _container=None)

display(RealtimeData)
# Out:
# {'cid': 5, 'wid': 422, 'WellName': 'GEMAH-80', 'RigName': 36    RIG#26
# Name: rig_name, dtype: string, 'ActiveDate': '2025-03-26', 'EndDate': '2025-04-30'}
#  Download Realtime Sensor Data, 0.0 % Complete
# (Timestamp('2025-04-06 00:00:00'), Timestamp('2025-04-06 01:00:00'))
# 200
#  Download Realtime Sensor Data, 10.0 % Complete
# (Timestamp('2025-04-06 01:00:00'), Timestamp('2025-04-06 02:00:00'))
# 200
#  Download Realtime Sensor Data, 20.0 % Complete
# (Timestamp('2025-04-06 02:00:00'), Timestamp('2025-04-06 03:00:00'))
# 200
#  Download Realtime Sensor Data, 30.0 % Complete
# (Timestamp('2025-04-06 03:00:00'), Timestamp('2025-04-06 04:00:00'))
# 200
#  Download Realtime Sensor Data, 40.0 % Complete
# (Timestamp('2025-04-06 04:00:00'), Timestamp('2025-04-06 05:00:00'))
# 200
#  Download Realtime Sensor Data, 50.0 % Complete
# (Timestamp('2025-04-06 05:00:00'), Timestamp('2025-04-06 06:00:00'))
# 200
#  Download Realtime Sensor Data, 60.0 % Complete
# (Timestamp('2025-04-06 06:00:00'), Timestamp('2025-04-06 07:00:00'))
# 200
#  Download Realtime Sensor Data, 70.0 % Complete
# (Timestamp('2025-04-06 07:00:00'), Timestamp('2025-04-06 08:00:00'))
# 200
#  Download Realtime Sensor Data, 80.0 % Complete
# (Timestamp('2025-04-06 08:00:00'), Timestamp('2025-04-06 09:00:00'))
# 200
#  Download Realtime Sensor Data, 90.0 % Complete
# (Timestamp('2025-04-06 09:00:00'), Timestamp('2025-04-06 10:00:00'))
# 200
# c:\Users\irsya\Documents\02_Work\01_OTHERS\01_PDU\MIH-Dashboard-Project\WITSML_Development\..\Streamlit_App_v3\PDU_Func\IO_Data.py:276: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   realtimeraw.loc[:, 'dt_relative'] = (realtimeraw['dt'] - realtimeraw['dt'].min()).dt.total_seconds()
# c:\Users\irsya\Documents\02_Work\01_OTHERS\01_PDU\MIH-Dashboard-Project\WITSML_Development\..\Streamlit_App_v3\PDU_Func\IO_Data.py:299: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   realtimeraw[list_cols] = realtimeraw[list_cols].astype(float)
#                       dt        date      time  bitdepth        md  blockpos  \
# 0    2025-04-06 00:00:00  2025-04-06  00:00:00  3407.300  3409.220    68.530
# 1    2025-04-06 00:00:05  2025-04-06  00:00:05  3407.300  3409.220    68.530
# 2    2025-04-06 00:00:10  2025-04-06  00:00:10  3407.300  3409.220    68.530
# 3    2025-04-06 00:00:15  2025-04-06  00:00:15  3407.300  3409.220    68.530
# 4    2025-04-06 00:00:20  2025-04-06  00:00:20  3407.300  3409.220    68.530
# ...                  ...         ...       ...       ...       ...       ...
# 7195 2025-04-06 09:59:35  2025-04-06  09:59:35  3528.500  3528.500     8.970
# 7196 2025-04-06 09:59:40  2025-04-06  09:59:40  3528.500  3528.500     8.970
# 7197 2025-04-06 09:59:45  2025-04-06  09:59:45  3528.500  3528.500     8.970
# 7198 2025-04-06 09:59:50  2025-04-06  09:59:50  3528.508  3528.508     8.962
# 7199 2025-04-06 09:59:55  2025-04-06  09:59:55  3528.510  3528.510     8.960
#
#         rop    hklda    woba  torqa   rpm  stppress  mudflowin
# 0      0.00  101.170   0.000   7.04  59.0  2562.890    908.830
# 1      0.00  101.000   0.000   6.99  60.0  2571.480    917.390
# 2      0.00  101.090   0.000   6.92  60.0  2561.330    923.600
# 3      0.00  101.130   0.000   6.98  60.0  2575.000    928.280
# 4      0.00  101.090   0.000   6.94  60.0  2566.800    931.420
# ...     ...      ...     ...    ...   ...       ...        ...
# 7195  62.07   75.492   9.988   0.00   0.0  2079.110    866.572
# 7196  62.07   75.300  10.180   0.00   0.0  2069.188    866.420
# 7197  62.07   75.300  10.180   0.00   0.0  2076.372    863.940
# 7198  62.07   75.924   9.556   0.00   0.0  2073.258    865.792
# 7199  62.07   76.080   9.400   0.00   0.0  2073.330    867.634
#
# [7200 rows x 13 columns]

# %% [markdown]
# ## Writing Function

# %%
from datetime import datetime

# from komle.bindings.v1411.read import witsml 
from komle.bindings.v1411.write import witsml
from komle import utils as ku

# %% Create logs, a container for obj_log

logs = witsml.logs(version=witsml.__version__)

# %%
WellInfoDict

for LogName in RealtimeData.columns:
    print(LogName)
    log = witsml.obj_log(
        uidWell=str(WellInfoDict['cid']) + str(WellInfoDict['wid']),
        uidWellbore="1",
        uid=str(WellInfoDict['cid']) + str(WellInfoDict['wid']),
        nameWell=WellInfoDict['WellName'],
        nameWellbore="1",
        name=LogName,
        logData=RealtimeData[LogName].tolist(),
    )
# Out:
# dt
# ---------------------------------------------------------------------------
# SimpleTypeValueError                      Traceback (most recent call last)
# Cell In[12], line 5
#       3 for LogName in RealtimeData.columns:
#       4     print(LogName)
# ----> 5     log = witsml.obj_log(
#       6         uidWell=str(WellInfoDict['cid']) + str(WellInfoDict['wid']),
#       7         uidWellbore="1",
#       8         uid=str(WellInfoDict['cid']) + str(WellInfoDict['wid']),
#       9         nameWell=WellInfoDict['WellName'],
#      10         nameWellbore="1",
#      11         name=LogName,
#      12         logData=RealtimeData[LogName].tolist(),
#      13     )
#
# File c:\Users\irsya\miniconda3\envs\pdu_4\lib\site-packages\pyxb\binding\basis.py:2118, in complexTypeDefinition.__init__(self, *args, **kw)
#    2116     if iv is not None:
#    2117         did_set_kw_elt = True
# -> 2118         fu.set(self, iv)
#    2119 if do_finalize_content_model is None:
#    2120     do_finalize_content_model = not did_set_kw_elt
#
# File c:\Users\irsya\miniconda3\envs\pdu_4\lib\site-packages\pyxb\binding\content.py:1043, in ElementDeclaration.set(self, ctd_instance, value)
#    1041 assert self.__elementBinding is not None
#    1042 if ctd_instance._validationConfig.forBinding or isinstance(value, pyxb.BIND):
# -> 1043     value = self.__elementBinding.compatibleValue(value, is_plural=self.isPlural())
#    1044 setattr(ctd_instance, self.__key, value)
#    1045 ctd_instance._addContent(basis.ElementContent(value, self))
#
# File c:\Users\irsya\miniconda3\envs\pdu_4\lib\site-packages\pyxb\binding\basis.py:1652, in element.compatibleValue(self, value, **kw)
#    1650     if not isinstance(value, collections.abc.Iterable):
#    1651         raise pyxb.SimplePluralValueError(self.typeDefinition(), value)
# -> 1652     return [ self.compatibleValue(_v) for _v in value ]
#    1653 compValue = self.typeDefinition()._CompatibleValue(value, **kw);
#    1654 if self.__fixed and (compValue != self.__defaultValue):
#
# File c:\Users\irsya\miniconda3\envs\pdu_4\lib\site-packages\pyxb\binding\basis.py:1652, in <listcomp>(.0)
#    1650     if not isinstance(value, collections.abc.Iterable):
#    1651         raise pyxb.SimplePluralValueError(self.typeDefinition(), value)
# -> 1652     return [ self.compatibleValue(_v) for _v in value ]
#    1653 compValue = self.typeDefinition()._CompatibleValue(value, **kw);
#    1654 if self.__fixed and (compValue != self.__defaultValue):
#
# File c:\Users\irsya\miniconda3\envs\pdu_4\lib\site-packages\pyxb\binding\basis.py:1653, in element.compatibleValue(self, value, **kw)
#    1651         raise pyxb.SimplePluralValueError(self.typeDefinition(), value)
#    1652     return [ self.compatibleValue(_v) for _v in value ]
# -> 1653 compValue = self.typeDefinition()._CompatibleValue(value, **kw);
#    1654 if self.__fixed and (compValue != self.__defaultValue):
#    1655     raise pyxb.ElementChangeError(self, value)
#
# File c:\Users\irsya\miniconda3\envs\pdu_4\lib\site-packages\pyxb\binding\basis.py:444, in _TypeBinding_mixin._CompatibleValue(cls, value, **kw)
#     437         return rv
#     439 # There may be other things that can be converted to the desired type,
#     440 # but we can't tell that from the type hierarchy.  Too many of those
#     441 # things result in an undesirable loss of information: for example,
#     442 # when an all model supports both numeric and string transitions, the
#     443 # candidate is a number, and the string transition is tested first.
# --> 444 raise pyxb.SimpleTypeValueError(cls, value)
#
# SimpleTypeValueError: Type {http://www.witsml.org/schemas/1series}cs_logData cannot be created from: 2025-04-06 00:00:00
